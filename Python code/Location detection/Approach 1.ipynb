# %% [markdown]
# # First approach
#  - mesh used A ,B and C
#  - p=3

# %%
from function import *
# Out:
# Using TensorFlow backend.

# %%
# Parameter 
nb_samples = 10000
batch = 100

Meshs = [ "mesh_A" ,"mesh_B" ,"mesh_C"]
Data_set = "\\data_set_p_3_all.csv"

# %%
for mesh in Meshs:
    print("=============================Model==================================")
    print(mesh)
    print(Data_set)
    All_results_angle = []
    All_results_dist = []
    All_test_mse = []
    for i in range(5):
        print( "rounds ", i+1)
        data_path = 'C:\\Users\\pierr\\Desktop\\Projet de semestre I\\data\\task_2\\train_set\\discontinuity_0_1\\'+mesh+Data_set
        
        # load the data 
        data = np.loadtxt(data_path, delimiter=',')
        
        data_sample = data_cut( data , nb_samples)
        # to make every model the same number of train and test in order to compar
        X_train, X_test, Y_train, Y_test, point_inter_test, true_angle_test = data_preparation_approach_1(data_sample)
        model = build_model_40(approach=1)
        train_mse,test_mse, results_angle ,results_dist = model_training(model,X_train,X_test,Y_train,Y_test, patience_ = 50 ,batch_size_=batch, plot=True ,approach=1)
        All_results_angle.append(results_angle)
        All_results_dist.append(results_dist)
        All_test_mse.append(test_mse)
    print(np.mean(np.asarray(All_results_angle),axis=0))
    print(np.mean(np.asarray(All_results_dist),axis=0))
    print(np.mean(np.asarray(All_test_mse),axis=0))
# Out:
# =============================Model==================================
# mesh_A
# \data_set_p_3_all.csv
# rounds  1
# Epoch 00584: early stopping
# ========================Summary angle=============================
# all value are in degree
#  the error mean is :  5.477811008997347
#  the error std is :  6.413630872469034
#  the median is :  3.6692350211984315
#  the min is :  0.0061226320454608185
#  the max is :  76.56034549287031
#  the accuracy up to 1    degree is :  14.6  %
#  the accuracy up to 5    degree is :  63.4  %
#  the accuracy up to 10    degree is :  86.2  %
# MSE angle test: 0.022
# MSE 2 angle test: 0.022
# ========================Summary distance=========================
# all value are in degree
#  the mse is :  0.012610165490088246
#  the error mean is :  0.08427199885115186
#  the error std is :  0.07421856708209683
#  the median is :  0.06220588856601986
#  the min is :  3.570077694944884e-05
#  the max is :  0.4055347583179161
# MSE Train: 0.010 | MSE Test: 0.010
# rounds  2
# Epoch 00403: early stopping
# ========================Summary angle=============================
# all value are in degree
#  the error mean is :  5.039361335447311
#  the error std is :  6.188572129024971
#  the median is :  3.484323592015123
#  the min is :  0.0003455013419273456
#  the max is :  77.41228483093062
#  the accuracy up to 1    degree is :  16.45  %
#  the accuracy up to 5    degree is :  64.4  %
#  the accuracy up to 10    degree is :  87.75  %
# MSE angle test: 0.024
# MSE 2 angle test: 0.019
# ========================Summary distance=========================
# all value are in degree
#  the mse is :  0.012806692199005643
#  the error mean is :  0.08420037304936442
#  the error std is :  0.07561077553731022
#  the median is :  0.062281541711667165
#  the min is :  1.3398673875397726e-05
#  the max is :  0.5391213666706274
# MSE Train: 0.009 | MSE Test: 0.011
# rounds  3
# Epoch 00485: early stopping
# ========================Summary angle=============================
# all value are in degree
#  the error mean is :  5.479769895395604
#  the error std is :  5.888650112841442
#  the median is :  3.615673847659398
#  the min is :  0.00285046927358934
#  the max is :  62.26793267742039
#  the accuracy up to 1    degree is :  15.85  %
#  the accuracy up to 5    degree is :  62.3  %
#  the accuracy up to 10    degree is :  84.3  %
# MSE angle test: 0.020
# MSE 2 angle test: 0.020
# ========================Summary distance=========================
# all value are in degree
#  the mse is :  0.013483461836202533
#  the error mean is :  0.08654632387490709
#  the error std is :  0.07741573263841285
#  the median is :  0.06495074021195615
#  the min is :  1.4935900184198658e-05
#  the max is :  0.572564808272191
# MSE Train: 0.010 | MSE Test: 0.011
# rounds  4
# Epoch 00682: early stopping
# ========================Summary angle=============================
# all value are in degree
#  the error mean is :  4.5126139518010495
#  the error std is :  4.600248281287249
#  the median is :  3.160657898449889
#  the min is :  0.00041974914599052227
#  the max is :  38.128935486809695
#  the accuracy up to 1    degree is :  16.8  %
#  the accuracy up to 5    degree is :  68.55  %
#  the accuracy up to 10    degree is :  90.15  %
# MSE angle test: 0.016
# MSE 2 angle test: 0.013
# ========================Summary distance=========================
# all value are in degree
#  the mse is :  0.0121314790443923
#  the error mean is :  0.08170939469690955
#  the error std is :  0.07385833644658502
#  the median is :  0.060614833051572115
#  the min is :  0.0001355208736795177
#  the max is :  0.5761713649429037
# MSE Train: 0.009 | MSE Test: 0.010
# rounds  5
# Epoch 00702: early stopping
# ========================Summary angle=============================
# all value are in degree
#  the error mean is :  5.5520895935986285
#  the error std is :  6.790380140023619
#  the median is :  3.676871008155553
#  the min is :  0.005268284791866584
#  the max is :  75.03242634526129
#  the accuracy up to 1    degree is :  14.4  %
#  the accuracy up to 5    degree is :  62.7  %
#  the accuracy up to 10    degree is :  85.75  %
# MSE angle test: 0.045
# MSE 2 angle test: 0.023
# ========================Summary distance=========================
# all value are in degree
#  the mse is :  0.013103917487334363
#  the error mean is :  0.08574438213764111
#  the error std is :  0.07584074379361357
#  the median is :  0.06438907527420795
#  the min is :  3.788977679172051e-05
#  the max is :  0.51094489759526
# MSE Train: 0.010 | MSE Test: 0.010
# [5.21232916e+00 5.97629631e+00 3.52135227e+00 3.00132732e-03
#  6.58803850e+01 1.56200000e+01 6.42700000e+01 8.68300000e+01]
# [1.28271432e-02 8.44944945e-02 7.53888311e-02 6.28884158e-02
#  4.74892003e-05 5.20867439e-01]
# 0.010456098803877831
# =============================Model==================================
# mesh_B
# \data_set_p_3_all.csv
# rounds  1
# Epoch 00524: early stopping
# ========================Summary angle=============================
# all value are in degree
#  the error mean is :  5.198757170019782
#  the error std is :  5.924088901947622
#  the median is :  3.6634281113808402
#  the min is :  0.0038376131623465426
#  the max is :  74.73894557773583
#  the accuracy up to 1    degree is :  14.75  %
#  the accuracy up to 5    degree is :  63.45  %
#  the accuracy up to 10    degree is :  88.25  %
# MSE angle test: 0.042
# MSE 2 angle test: 0.019
# ========================Summary distance=========================
# all value are in degree
#  the mse is :  0.012403736753893559
#  the error mean is :  0.08334455114085144
#  the error std is :  0.07387437004146673
#  the median is :  0.06189142045370327
#  the min is :  6.057763030975494e-06
#  the max is :  0.5642057293233138
# MSE Train: 0.009 | MSE Test: 0.010
# rounds  2
# Epoch 00402: early stopping
# ========================Summary angle=============================
# all value are in degree
#  the error mean is :  5.5803403134169125
#  the error std is :  9.211033858091684
#  the median is :  3.390589483057486
#  the min is :  0.007969704996012794
#  the max is :  137.17460452350974
#  the accuracy up to 1    degree is :  15.65  %
#  the accuracy up to 5    degree is :  65.9  %
#  the accuracy up to 10    degree is :  87.2  %
# MSE angle test: 0.060
# MSE 2 angle test: 0.035
# ========================Summary distance=========================
# all value are in degree
#  the mse is :  0.012410493528577312
#  the error mean is :  0.08508543554357353
#  the error std is :  0.07190940263232412
#  the median is :  0.06513642281090462
#  the min is :  5.9157481786087374e-05
#  the max is :  0.43033668785010026
# MSE Train: 0.009 | MSE Test: 0.010
# rounds  3
# Epoch 00588: early stopping
# ========================Summary angle=============================
# all value are in degree
#  the error mean is :  5.113436383276055
#  the error std is :  6.256570001162835
#  the median is :  3.3460037256095436
#  the min is :  0.0004538710278580993
#  the max is :  84.88756300661416
#  the accuracy up to 1    degree is :  16.1  %
#  the accuracy up to 5    degree is :  66.3  %
#  the accuracy up to 10    degree is :  87.2  %
# MSE angle test: 0.020
# MSE 2 angle test: 0.020
# ========================Summary distance=========================
# all value are in degree
#  the mse is :  0.012190336360580967
#  the error mean is :  0.08314252718669553
#  the error std is :  0.07264748126115979
#  the median is :  0.06241548761651991
#  the min is :  6.716294161118741e-05
#  the max is :  0.41501421899211555
# MSE Train: 0.009 | MSE Test: 0.010
# rounds  4
# Epoch 00438: early stopping
# ========================Summary angle=============================
# all value are in degree
#  the error mean is :  5.431894740068372
#  the error std is :  7.635525649874515
#  the median is :  3.4867997603512535
#  the min is :  0.0017504800884573513
#  the max is :  152.49211224881424
#  the accuracy up to 1    degree is :  15.6  %
#  the accuracy up to 5    degree is :  64.75  %
#  the accuracy up to 10    degree is :  86.75  %
# MSE angle test: 0.041
# MSE 2 angle test: 0.027
# ========================Summary distance=========================
# all value are in degree
#  the mse is :  0.01234032405220228
#  the error mean is :  0.08196839209173003
#  the error std is :  0.07497670805055855
#  the median is :  0.06187726777698571
#  the min is :  2.092362112415813e-05
#  the max is :  0.6103532784784933
# MSE Train: 0.009 | MSE Test: 0.010
# rounds  5
# Epoch 00395: early stopping
# ========================Summary angle=============================
# all value are in degree
#  the error mean is :  6.492416981599821
#  the error std is :  9.230799004991713
#  the median is :  3.9188025340413013
#  the min is :  0.0011476037713933351
#  the max is :  155.97528336094413
#  the accuracy up to 1    degree is :  14.2  %
#  the accuracy up to 5    degree is :  59.25  %
#  the accuracy up to 10    degree is :  83.05  %
# MSE angle test: 0.052
# MSE 2 angle test: 0.039
# ========================Summary distance=========================
# all value are in degree
#  the mse is :  0.012003635887493383
#  the error mean is :  0.08220722576532014
#  the error std is :  0.07242656915430323
#  the median is :  0.0628095702890202
#  the min is :  0.00010291633429737601
#  the max is :  0.42041344537403225
# MSE Train: 0.009 | MSE Test: 0.010
# [5.56336912e+00 7.65160348e+00 3.56112472e+00 3.03185461e-03
#  1.21053702e+02 1.52600000e+01 6.39300000e+01 8.64900000e+01]
# [1.22697053e-02 8.31496263e-02 7.31669062e-02 6.28260338e-02
#  5.12436284e-05 4.88064672e-01]
# 0.00982852479070425
# =============================Model==================================
# mesh_C
# \data_set_p_3_all.csv
# rounds  1
# Epoch 00623: early stopping
# ========================Summary angle=============================
# all value are in degree
#  the error mean is :  6.153047921587122
#  the error std is :  7.350944405210645
#  the median is :  4.1272406050145864
#  the min is :  0.0037030134250244373
#  the max is :  99.65037900907551
#  the accuracy up to 1    degree is :  12.7  %
#  the accuracy up to 5    degree is :  58.1  %
#  the accuracy up to 10    degree is :  82.85  %
# MSE angle test: 0.028
# MSE 2 angle test: 0.028
# ========================Summary distance=========================
# all value are in degree
#  the mse is :  0.01523687400617672
#  the error mean is :  0.09155024887883936
#  the error std is :  0.08279749957818346
#  the median is :  0.06816348456228316
#  the min is :  4.397652990428824e-06
#  the max is :  0.570677704930064
# MSE Train: 0.013 | MSE Test: 0.015
# rounds  2
# Epoch 00686: early stopping
# ========================Summary angle=============================
# all value are in degree
#  the error mean is :  6.554116886745987
#  the error std is :  7.768910295123601
#  the median is :  4.409647654897256
#  the min is :  0.0004923291962697363
#  the max is :  158.11868478940073
#  the accuracy up to 1    degree is :  13.7  %
#  the accuracy up to 5    degree is :  54.95  %
#  the accuracy up to 10    degree is :  79.5  %
# MSE angle test: 0.057
# MSE 2 angle test: 0.031
# ========================Summary distance=========================
# all value are in degree
#  the mse is :  0.01519932999790953
#  the error mean is :  0.09066856418150805
#  the error std is :  0.08353766496122145
#  the median is :  0.06850839946731266
#  the min is :  0.00011509190219372023
#  the max is :  0.7651923338859548
# MSE Train: 0.013 | MSE Test: 0.015
# rounds  3
# Epoch 00427: early stopping
# ========================Summary angle=============================
# all value are in degree
#  the error mean is :  6.286865061230506
#  the error std is :  7.709472221052214
#  the median is :  4.221681385626631
#  the min is :  0.0013990296824809567
#  the max is :  149.11307236324657
#  the accuracy up to 1    degree is :  14.2  %
#  the accuracy up to 5    degree is :  57.45  %
#  the accuracy up to 10    degree is :  81.3  %
# MSE angle test: 0.059
# MSE 2 angle test: 0.030
# ========================Summary distance=========================
# all value are in degree
#  the mse is :  0.014536322968339776
#  the error mean is :  0.09112217737835392
#  the error std is :  0.07894980530797768
#  the median is :  0.0701156543413618
#  the min is :  0.00013323924285879585
#  the max is :  0.5573728821416707
# MSE Train: 0.013 | MSE Test: 0.015
# rounds  4
# Epoch 00636: early stopping
# ========================Summary angle=============================
# all value are in degree
#  the error mean is :  6.616113307434405
#  the error std is :  9.398317954162335
#  the median is :  4.081527373058368
#  the min is :  0.00841634602000596
#  the max is :  163.9141293507537
#  the accuracy up to 1    degree is :  12.9  %
#  the accuracy up to 5    degree is :  57.35  %
#  the accuracy up to 10    degree is :  80.5  %
# MSE angle test: 0.085
# MSE 2 angle test: 0.040
# ========================Summary distance=========================
# all value are in degree
#  the mse is :  0.015101944819888575
#  the error mean is :  0.0909092697492575
#  the error std is :  0.08268887164271446
#  the median is :  0.06952713863724447
#  the min is :  4.027623317914841e-06
#  the max is :  0.7275097248175308
# MSE Train: 0.013 | MSE Test: 0.015
# rounds  5
# Epoch 00546: early stopping
# ========================Summary angle=============================
# all value are in degree
#  the error mean is :  6.519021602493573
#  the error std is :  10.423613493444934
#  the median is :  4.101658388741418
#  the min is :  0.014688590792946155
#  the max is :  167.6150605826959
#  the accuracy up to 1    degree is :  15.0  %
#  the accuracy up to 5    degree is :  58.25  %
#  the accuracy up to 10    degree is :  81.4  %
# MSE angle test: 0.101
# MSE 2 angle test: 0.046
# ========================Summary distance=========================
# all value are in degree
#  the mse is :  0.0159518157205436
#  the error mean is :  0.09352964915370901
#  the error std is :  0.08487650116332379
#  the median is :  0.06898346130893557
#  the min is :  8.1476097931521e-05
#  the max is :  0.6348283752013582
# MSE Train: 0.013 | MSE Test: 0.015
# [6.42583296e+00 8.53025167e+00 4.18835108e+00 5.73986182e-03
#  1.47682265e+02 1.37000000e+01 5.72200000e+01 8.11100000e+01]
# [1.52052575e-02 9.15559819e-02 8.25700685e-02 6.90596277e-02
#  6.76465039e-05 6.51116204e-01]
# 0.015154582316428421
