# %% [markdown]
# ## First approach
#
#    - p = 3
#    - discontinuity 0 , 1
#    - Mesh A, B, C
#    - with _ , _close , _all

# %%
from fonction import *
from models import *
# Out:
# Using TensorFlow backend.

# %%
# Parameter 
nb_samples = 10000
modifie_angle = False 
modifie_loss = False
batch = 100
All_results = []
All_train_mse = []
All_test_mse = []
save_model = []
All_who = []

Meshs = [ "mesh_A" ,"mesh_B" ,"mesh_C"]
Architectures = [ build_model_10 , build_model_22 , build_model_40 ]
Data_sets = [ "\\data_set_p_3_.csv","\\data_set_p_3_close.csv","\\data_set_p_3_all.csv" ]

# %%
for mesh in Meshs:
    for ind_data , data_set in enumerate(Data_sets) :
        print("=============================Model==================================")
        print(mesh)
        print(data_set)
        All_who.append(mesh+data_set)
        data_path = 'C:\\Users\\pierr\\Desktop\\Projet de semestre I\\data\\train_set\\discontinuity_0_1\\'+mesh+data_set
        
        # load the data 
        data = np.loadtxt(data_path, delimiter=',')
        ind = data[:,0]
        data= data[:,1:]
        data_sample = data_cut( data , nb_samples)
        # to make every model the same number of train and test in order to compar
        X_train, X_test, Y_train, Y_test, indice_neg_data = data_preparation(data_sample,modifie_angle)
        model, train_mse , test_mse,results = training_NN(Architectures[ind_data],X_train, X_test, Y_train, Y_test,batch = batch,modifie_loss =modifie_loss )
        save_model.append(model)
        All_results.append(results)
        All_train_mse.append(train_mse)
        All_test_mse.append(test_mse)
# Out:
# =============================Model==================================
# mesh_A
# \data_set_p_3_.csv
# ===================NN architecture==========================
# =======================training=============================
# Epoch 00411: early stopping
# ========================Summary=============================
# all value are in degree
#  the error mean is :  42.69030009329642
#  the error std is :  51.69801488904309
#  the median is :  16.383241853082573
#  the max is :  225.65427390886978
#  the min is :  0.011194150679088466
#  the accuracy up to 1    degree is :  4.15  %
#  the accuracy up to 5    degree is :  22.7  %
#  the accuracy up to 10    degree is :  39.3  %
# MSE Train: 1.333 | MSE Test: 1.369
# Training time is : 0.34  minute
# =============================Model==================================
# mesh_A
# \data_set_p_3_close.csv
# ===================NN architecture==========================
# =======================training=============================
# Epoch 00503: early stopping
# ========================Summary=============================
# all value are in degree
#  the error mean is :  38.249019439248926
#  the error std is :  48.45975501111177
#  the median is :  13.593979825650564
#  the max is :  231.91044768712737
#  the min is :  0.005842172639560772
#  the accuracy up to 1    degree is :  5.75  %
#  the accuracy up to 5    degree is :  23.85  %
#  the accuracy up to 10    degree is :  42.25  %
# MSE Train: 1.165 | MSE Test: 1.161
# Training time is : 0.43  minute
# =============================Model==================================
# mesh_A
# \data_set_p_3_all.csv
# ===================NN architecture==========================
# =======================training=============================
# Epoch 00159: early stopping
# ========================Summary=============================
# all value are in degree
#  the error mean is :  9.77813392667357
#  the error std is :  24.139299794730913
#  the median is :  4.399480713870588
#  the max is :  313.06345390322326
#  the min is :  0.021219035831535393
#  the accuracy up to 1    degree is :  11.65  %
#  the accuracy up to 5    degree is :  55.85  %
#  the accuracy up to 10    degree is :  82.15  %
# MSE Train: 0.125 | MSE Test: 0.207
# Training time is : 0.16  minute
# =============================Model==================================
# mesh_B
# \data_set_p_3_.csv
# ===================NN architecture==========================
# =======================training=============================
# Epoch 00374: early stopping
# ========================Summary=============================
# all value are in degree
#  the error mean is :  88.72974926580454
#  the error std is :  33.6561653322118
#  the median is :  88.32687350537942
#  the max is :  236.46933952888392
#  the min is :  0.14871165137852316
#  the accuracy up to 1    degree is :  0.35  %
#  the accuracy up to 5    degree is :  1.15  %
#  the accuracy up to 10    degree is :  1.95  %
# MSE Train: 2.771 | MSE Test: 2.743
# Training time is : 0.32  minute
# =============================Model==================================
# mesh_B
# \data_set_p_3_close.csv
# ===================NN architecture==========================
# =======================training=============================
# Epoch 00141: early stopping
# ========================Summary=============================
# all value are in degree
#  the error mean is :  88.58691080685269
#  the error std is :  34.04308668700585
#  the median is :  88.98443490783151
#  the max is :  197.97639921763817
#  the min is :  0.48905174275293817
#  the accuracy up to 1    degree is :  0.15  %
#  the accuracy up to 5    degree is :  0.95  %
#  the accuracy up to 10    degree is :  2.05  %
# MSE Train: 2.727 | MSE Test: 2.744
# Training time is : 0.13  minute
# =============================Model==================================
# mesh_B
# \data_set_p_3_all.csv
# ===================NN architecture==========================
# =======================training=============================
# Epoch 00130: early stopping
# ========================Summary=============================
# all value are in degree
#  the error mean is :  85.95572663751999
#  the error std is :  32.441976117497475
#  the median is :  86.43166846885725
#  the max is :  248.54853229149668
#  the min is :  0.41480868116269676
#  the accuracy up to 1    degree is :  0.05  %
#  the accuracy up to 5    degree is :  0.5  %
#  the accuracy up to 10    degree is :  1.15  %
# MSE Train: 2.303 | MSE Test: 2.571
# Training time is : 0.12  minute
# =============================Model==================================
# mesh_C
# \data_set_p_3_.csv
# ===================NN architecture==========================
# =======================training=============================
# Epoch 00161: early stopping
# ========================Summary=============================
# all value are in degree
#  the error mean is :  87.0609297396835
#  the error std is :  38.245523007582996
#  the median is :  85.95106781913285
#  the max is :  207.14244396068804
#  the min is :  0.024680098025823938
#  the accuracy up to 1    degree is :  0.15  %
#  the accuracy up to 5    degree is :  0.9  %
#  the accuracy up to 10    degree is :  2.2  %
# MSE Train: 2.776 | MSE Test: 2.754
# Training time is : 0.14  minute
# =============================Model==================================
# mesh_C
# \data_set_p_3_close.csv
# ===================NN architecture==========================
# =======================training=============================
# Epoch 00193: early stopping
# ========================Summary=============================
# all value are in degree
#  the error mean is :  89.23038461826842
#  the error std is :  37.1121786756981
#  the median is :  87.2497820027429
#  the max is :  200.6888126657517
#  the min is :  0.29972682437526443
#  the accuracy up to 1    degree is :  0.15  %
#  the accuracy up to 5    degree is :  0.6  %
#  the accuracy up to 10    degree is :  2.1  %
# MSE Train: 2.770 | MSE Test: 2.845
# Training time is : 0.17  minute
# =============================Model==================================
# mesh_C
# \data_set_p_3_all.csv
# ===================NN architecture==========================
# =======================training=============================
# Epoch 00119: early stopping
# ========================Summary=============================
# all value are in degree
#  the error mean is :  86.6730170036359
#  the error std is :  38.38034789344005
#  the median is :  83.71866102865285
#  the max is :  346.3647729962069
#  the min is :  1.1572655333946806
#  the accuracy up to 1    degree is :  0.0  %
#  the accuracy up to 5    degree is :  0.35  %
#  the accuracy up to 10    degree is :  0.75  %
# MSE Train: 2.361 | MSE Test: 2.737
# Training time is : 0.11  minute
