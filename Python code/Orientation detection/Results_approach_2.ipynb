# %% [markdown]
# ## Second approach
#
#    - p = 3
#    - discontinuity 0 , 1
#    - Mesh A, B, C
#    - with _ , _close , _all

# %%
from fonction import *
from models import *
# Out:
# Using TensorFlow backend.

# %%
# Parameter 
nb_samples = 10000
modifie_angle = True 
modifie_loss = False
batch = 100
All_results = []
All_train_mse = []
All_test_mse = []
save_model = []
All_who = []

Meshs = [ "mesh_A" ,"mesh_B" ,"mesh_C"]
Architectures = [ build_model_10 , build_model_22 , build_model_40 ]
Data_sets = [ "\\data_set_p_3_.csv","\\data_set_p_3_close.csv","\\data_set_p_3_all.csv" ]

# %%
for mesh in Meshs:
    for ind_data , data_set in enumerate(Data_sets) :
        print("=============================Model==================================")
        print(mesh)
        print(data_set)
        All_who.append(mesh+data_set)
        data_path = 'C:\\Users\\pierr\\Desktop\\Projet de semestre I\\data\\train_set\\discontinuity_0_1\\'+mesh+data_set
        
        # load the data 
        data = np.loadtxt(data_path, delimiter=',')
        ind = data[:,0]
        data= data[:,1:]
        data_sample = data_cut( data , nb_samples)
        # to make every model the same number of train and test in order to compar
        X_train, X_test, Y_train, Y_test, indice_neg_data = data_preparation(data_sample,modifie_angle)
        model, train_mse , test_mse,results = training_NN(Architectures[ind_data],X_train, X_test, Y_train, Y_test,batch = batch,modifie_loss =modifie_loss )
        save_model.append(model)
        All_results.append(results)
        All_train_mse.append(train_mse)
        All_test_mse.append(test_mse)
# Out:
# =============================Model==================================
# mesh_A
# \data_set_p_3_.csv
# ===================NN architecture==========================
# =======================training=============================
# Epoch 00298: early stopping
# ========================Summary=============================
# all value are in degree
#  the error mean is :  19.905201591622845
#  the error std is :  22.502400064790123
#  the median is :  10.741913284063727
#  the max is :  105.72802554137533
#  the min is :  0.0003020035132834664
#  the accuracy up to 1    degree is :  4.9  %
#  the accuracy up to 5    degree is :  27.0  %
#  the accuracy up to 10    degree is :  48.6  %
# MSE Train: 0.265 | MSE Test: 0.275
# Training time is : 0.26  minute
# =============================Model==================================
# mesh_A
# \data_set_p_3_close.csv
# ===================NN architecture==========================
# =======================training=============================
# Epoch 00312: early stopping
# ========================Summary=============================
# all value are in degree
#  the error mean is :  18.207908122034937
#  the error std is :  21.346372809301382
#  the median is :  9.761976454272805
#  the max is :  106.82504635853923
#  the min is :  0.0003640345670916645
#  the accuracy up to 1    degree is :  6.2  %
#  the accuracy up to 5    degree is :  28.75  %
#  the accuracy up to 10    degree is :  50.8  %
# MSE Train: 0.251 | MSE Test: 0.240
# Training time is : 0.27  minute
# =============================Model==================================
# mesh_A
# \data_set_p_3_all.csv
# ===================NN architecture==========================
# =======================training=============================
# Epoch 00410: early stopping
# ========================Summary=============================
# all value are in degree
#  the error mean is :  5.1285526407696045
#  the error std is :  11.487884375935248
#  the median is :  2.978562051492929
#  the max is :  176.36672958040165
#  the min is :  9.947806807986126e-05
#  the accuracy up to 1    degree is :  18.75  %
#  the accuracy up to 5    degree is :  70.65  %
#  the accuracy up to 10    degree is :  92.55  %
# MSE Train: 0.045 | MSE Test: 0.048
# Training time is : 0.37  minute
# =============================Model==================================
# mesh_B
# \data_set_p_3_.csv
# ===================NN architecture==========================
# =======================training=============================
# Epoch 00503: early stopping
# ========================Summary=============================
# all value are in degree
#  the error mean is :  20.595505846932035
#  the error std is :  23.59048375489862
#  the median is :  11.175466002580222
#  the max is :  106.49281723182247
#  the min is :  0.0016503138367909287
#  the accuracy up to 1    degree is :  5.2  %
#  the accuracy up to 5    degree is :  26.15  %
#  the accuracy up to 10    degree is :  46.05  %
# MSE Train: 0.311 | MSE Test: 0.299
# Training time is : 0.44  minute
# =============================Model==================================
# mesh_B
# \data_set_p_3_close.csv
# ===================NN architecture==========================
# =======================training=============================
# Epoch 00231: early stopping
# ========================Summary=============================
# all value are in degree
#  the error mean is :  20.72704902169267
#  the error std is :  23.40843554966408
#  the median is :  10.93601649593651
#  the max is :  105.31846719321274
#  the min is :  0.010532418426421941
#  the accuracy up to 1    degree is :  5.4  %
#  the accuracy up to 5    degree is :  25.65  %
#  the accuracy up to 10    degree is :  46.55  %
# MSE Train: 0.319 | MSE Test: 0.298
# Training time is : 0.20  minute
# =============================Model==================================
# mesh_B
# \data_set_p_3_all.csv
# ===================NN architecture==========================
# =======================training=============================
# Epoch 00133: early stopping
# ========================Summary=============================
# all value are in degree
#  the error mean is :  7.147148621028819
#  the error std is :  15.60574020076287
#  the median is :  3.6015847064657933
#  the max is :  127.50120875143091
#  the min is :  0.0039045642300834515
#  the accuracy up to 1    degree is :  15.45  %
#  the accuracy up to 5    degree is :  63.5  %
#  the accuracy up to 10    degree is :  87.6  %
# MSE Train: 0.079 | MSE Test: 0.090
# Training time is : 0.13  minute
# =============================Model==================================
# mesh_C
# \data_set_p_3_.csv
# ===================NN architecture==========================
# =======================training=============================
# Epoch 00347: early stopping
# ========================Summary=============================
# all value are in degree
#  the error mean is :  22.177665401550257
#  the error std is :  25.592939174309684
#  the median is :  11.080641611081777
#  the max is :  111.8371548967938
#  the min is :  0.0003389333120367155
#  the accuracy up to 1    degree is :  6.45  %
#  the accuracy up to 5    degree is :  26.8  %
#  the accuracy up to 10    degree is :  47.45  %
# MSE Train: 0.367 | MSE Test: 0.349
# Training time is : 0.29  minute
# =============================Model==================================
# mesh_C
# \data_set_p_3_close.csv
# ===================NN architecture==========================
# =======================training=============================
# Epoch 00324: early stopping
# ========================Summary=============================
# all value are in degree
#  the error mean is :  22.98651053168335
#  the error std is :  26.33481657372392
#  the median is :  11.003007181283891
#  the max is :  105.32042061312364
#  the min is :  0.005545708690647189
#  the accuracy up to 1    degree is :  5.9  %
#  the accuracy up to 5    degree is :  27.9  %
#  the accuracy up to 10    degree is :  47.0  %
# MSE Train: 0.351 | MSE Test: 0.372
# Training time is : 0.28  minute
# =============================Model==================================
# mesh_C
# \data_set_p_3_all.csv
# ===================NN architecture==========================
# =======================training=============================
# Epoch 00178: early stopping
# ========================Summary=============================
# all value are in degree
#  the error mean is :  9.47447677377334
#  the error std is :  19.9372283212691
#  the median is :  4.137938095106582
#  the max is :  169.42237171070795
#  the min is :  0.00034775087590332987
#  the accuracy up to 1    degree is :  14.25  %
#  the accuracy up to 5    degree is :  58.1  %
#  the accuracy up to 10    degree is :  82.6  %
# MSE Train: 0.112 | MSE Test: 0.148
# Training time is : 0.17  minute
