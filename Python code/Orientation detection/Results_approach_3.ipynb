# %% [markdown]
# ## Third approach
#
#    - p = 3
#    - discontinuity 0 , 1
#    - Mesh A, B, C
#    - with _ , _close , _all

# %%
from fonction import *
from models import *
# Out:
# Using TensorFlow backend.

# %%
# Parameter 
nb_samples = 10000
modifie_angle = True 
modifie_loss = True
batch = 100
All_results = []
All_train_mse = []
All_test_mse = []
save_model = []
All_who = []

Meshs = [ "mesh_A" ,"mesh_B" ,"mesh_C"]
Architectures = [ build_model_10_cust_loss , build_model_22_cust_loss , build_model_40_cust_loss ]
Data_sets = [ "\\data_set_p_3_.csv","\\data_set_p_3_close.csv","\\data_set_p_3_all.csv" ]

# %%
for mesh in Meshs:
    for ind_data , data_set in enumerate(Data_sets) :
        print("=============================Model==================================")
        print(mesh)
        print(data_set)
        All_who.append(mesh+data_set)
        data_path = 'C:\\Users\\pierr\\Desktop\\Projet de semestre I\\data\\train_set\\discontinuity_0_1\\'+mesh+data_set
        
        # load the data 
        data = np.loadtxt(data_path, delimiter=',')
        ind = data[:,0]
        data= data[:,1:]
        data_sample = data_cut( data , nb_samples)
        # to make every model the same number of train and test in order to compar
        X_train, X_test, Y_train, Y_test, indice_neg_data = data_preparation(data_sample,modifie_angle)
        model, train_mse , test_mse,results = training_NN(Architectures[ind_data],X_train, X_test, Y_train, Y_test,batch = batch,modifie_loss =modifie_loss )
        save_model.append(model)
        All_results.append(results)
        All_train_mse.append(train_mse)
        All_test_mse.append(test_mse)
# Out:
# =============================Model==================================
# mesh_A
# \data_set_p_3_.csv
# ===================NN architecture==========================
# =======================training=============================
# Epoch 00253: early stopping
# MSE modifie Test: 0.187
# ========================Summary=============================
# all value are in degree
#  the error mean is :  16.47124503759056
#  the error std is :  18.527716152278344
#  the median is :  9.752371070497588
#  the max is :  95.38006134232432
#  the min is :  0.009570030097762583
#  the accuracy up to 1    degree is :  5.95  %
#  the accuracy up to 5    degree is :  28.35  %
#  the accuracy up to 10    degree is :  50.85  %
# MSE Train: 0.171 | MSE Test: 0.187
# Training time is : 0.23  minute
# =============================Model==================================
# mesh_A
# \data_set_p_3_close.csv
# ===================NN architecture==========================
# ...
